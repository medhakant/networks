# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = []
for x in range(100):
    v = np.random.randn(2)
    a.append(v)
    print(v)
# Out:
# [-1.92973099  1.14581651]
# [-1.40767352 -0.00834521]
# [-0.8103425  0.3945341]
# [-0.81563402 -0.01254063]
# [-0.2068101   0.22112984]
# [-0.95770695 -1.37585513]
# [ 0.88936392 -0.2418122 ]
# [ 0.32318594 -0.89322605]
# [-0.0356222  -2.27614501]
# [-0.4682455   0.87812344]
# [ 0.40675908 -0.60126795]
# [-0.49529207  0.15823714]
# [-0.01607191 -1.46026227]
# [0.23700448 1.17932296]
# [ 0.42537874 -2.84842176]
# [0.8060819  2.55308186]
# [-0.04300463 -1.03348067]
# [1.2864036 1.0167015]
# [-0.01458951 -0.47530472]
# [-0.45649379 -0.19819973]
# [0.29030945 0.04035985]
# [0.71747234 0.17650059]
# [-0.84554858 -0.77807691]
# [-0.12325793  1.51799237]
# [0.49173195 0.05388688]
# [-0.09265122 -1.26301437]
# [-0.24874734  1.41156651]
# [ 0.40376457 -0.48880296]
# [ 1.47875841 -0.34007828]
# [0.31863501 0.64186308]
# [ 0.41534134 -0.00736179]
# [-0.37614468  0.49993066]
# [ 0.22004554 -1.16507262]
# [-0.49872207  0.49697632]
# [ 0.62009702 -0.55546026]
# [-0.36198516 -0.38049369]
# ...

# %%
a
# Out:
# [array([-1.92973099,  1.14581651]),
#  array([-1.40767352, -0.00834521]),
#  array([-0.8103425,  0.3945341]),
#  array([-0.81563402, -0.01254063]),
#  array([-0.2068101 ,  0.22112984]),
#  array([-0.95770695, -1.37585513]),
#  array([ 0.88936392, -0.2418122 ]),
#  array([ 0.32318594, -0.89322605]),
#  array([-0.0356222 , -2.27614501]),
#  array([-0.4682455 ,  0.87812344]),
#  array([ 0.40675908, -0.60126795]),
#  array([-0.49529207,  0.15823714]),
#  array([-0.01607191, -1.46026227]),
#  array([0.23700448, 1.17932296]),
#  array([ 0.42537874, -2.84842176]),
#  array([0.8060819 , 2.55308186]),
#  array([-0.04300463, -1.03348067]),
#  array([1.2864036, 1.0167015]),
#  array([-0.01458951, -0.47530472]),
#  array([-0.45649379, -0.19819973]),
#  array([0.29030945, 0.04035985]),
#  array([0.71747234, 0.17650059]),
#  array([-0.84554858, -0.77807691]),
#  array([-0.12325793,  1.51799237]),
#  array([0.49173195, 0.05388688]),
#  array([-0.09265122, -1.26301437]),
# ...

# %%
a = np.array(a)

# %%
a.shape
# Out:
# (100, 2)

# %%
plt.plot(a[:,0],a[:,1])
